# %% [markdown]
# # Step 1: Import Required Packages

# %%
import os

from dotenv import load_dotenv

from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    GoogleGenerativeAIEmbeddings
)

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_chroma import Chroma

from langchain_core.documents import Document

from langchain_core.messages import (
    HumanMessage,
    AIMessage,
    SystemMessage
)
# Out:
# C:\Users\Rohit singh\AppData\Local\Temp\ipykernel_9396\3163036107.py:10: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# # Step 2: Load PDF

# %%
# Step 2: Load PDF

pdf_path = "data/Python_Notes.pdf"
loader = PyPDFLoader(pdf_path)

documents = loader.load()

print("PDF loaded successfully")
print("Total pages:", len(documents))
# Out:
# PDF loaded successfully
# Total pages: 61

# %% [markdown]
# # Step 3: Split Documents into Chunks

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print("Documents split into chunks successfully")
print("Total chunks:", len(chunks))
# Out:
# Documents split into chunks successfully
# Total chunks: 107

# %%
print(chunks[0].page_content)
# Out:
# 1
#
# PREFACE
# Welcome to the “Ultimate Python Programming Handbook," your comprehensive guide to
# mastering Python programming. This handbook is designed for beginners and anyone looking to
# strengthen their foundational knowledge of Python, a versatile and user-friendly programming
# language.
# PURPOSE AND AUDIENCE
# This handbook aims to make programming accessible and enjoyable for everyone. Whether
# you're a student new to coding, a professional seeking to enhance your skills, or an enthusiast
# exploring Python, this handbook will definitely be helpful. Python's simplicity and readability
# make it an ideal starting point for anyone interested in programming.
# STRUCTURE AND CONTENT
# The handbook is divided into clear, concise chapters, each focused on a specific aspect of
# Python:
# • Fundamental Concepts: Start with the basics, such as installing Python and writing your
# first program.
# • Practical Examples: Illustrative examples and sample code demonstrate the

# %%
print(chunks[0].metadata)
# Out:
# {'producer': '3.0.10 (5.0.18)', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-16T02:12:11+05:30', 'author': 'Harry Codes', 'moddate': '2024-06-15T22:44:10+02:00', 'source': 'data/Python_Notes.pdf', 'total_pages': 61, 'page': 1, 'page_label': '2'}

# %% [markdown]
# # Step 4: Create Embeddings

# %%
load_dotenv()

google_api_key = os.getenv("GEMINI_API_KEY")

if not google_api_key:
    print("GEMINI_API_KEY not found")
else:
    embeddings = GoogleGenerativeAIEmbeddings(
        model="models/gemini-embedding-001",
        google_api_key=google_api_key
    )

    print("Embedding model initialized successfully")
# Out:
# Embedding model initialized successfully

# %%
# Test Embedding

test_text = "What is machine learning?"

vector = embeddings.embed_query(test_text)

print("Vector dimensions:", len(vector))
print("First 10 values:", vector[:10])
# Out:
# Vector dimensions: 3072
# First 10 values: [-0.02689046, 0.012816175, -0.009027316, -0.058475167, -0.019788653, 0.010473229, -0.007066461, 0.0018563827, 0.012909309, 0.041982897]

# %% [markdown]
# # Step 5: Vector Database

# %%
# Step 5: Store Chunks in Vector Database

from time import sleep

vector_store = Chroma(
    collection_name="rag_documents",
    embedding_function=embeddings,
    persist_directory="chroma_db"
)

batch_size = 20

for i in range(0, len(chunks), batch_size):
    batch = chunks[i:i + batch_size]

    vector_store.add_documents(batch)

    print(f"Stored {min(i + batch_size, len(chunks))}/{len(chunks)} chunks")

    # Small delay between batches
    sleep(5)

print("All documents stored successfully")
# Out:
# Stored 20/107 chunks
# Stored 40/107 chunks
# Stored 60/107 chunks
# Stored 80/107 chunks
# Stored 100/107 chunks
# Stored 107/107 chunks
# All documents stored successfully

# %% [markdown]
# # Step 6: Create Retriever

# %%
# Create and Test Retriever

retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)

# Test Retriever
query = "What is machine learning?"

relevant_docs = retriever.invoke(query)

print("Relevant chunks found:", len(relevant_docs))

for i, doc in enumerate(relevant_docs, start=1):
    print(f"\n--- Chunk {i} ---")
    print(doc.page_content[:500])
    print("Metadata:", doc.metadata)
# Out:
# Relevant chunks found: 3
#
# --- Chunk 1 ---
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ...
# Metadata: {'total_pages': 61, 'moddate': '2024-06-15T22:44:10+02:00', 'creator': 'Microsoft® Word for Microsoft 365', 'author': 'Harry Codes', 'page_label': '3', 'source': 'data/Python_Notes.pdf', 'creationdate': '2024-06-16T02:12:11+05:30', 'page': 2, 'producer': '3.0.10 (5.0.18)'}
#
# --- Chunk 2 ---
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ...
# Metadata: {'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-06-16T02:12:11+05:30', 'page': 2, 'author': 'Harry Codes', 'moddate': '2024-06-15T22:44:10+02:00', 'producer': '3.0.10 (5.0.18)', 'total_pages': 61, 'source': 'data/Python_Notes.pdf', 'page_label': '3'}
#
# --- Chunk 3 ---
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ...
# Metadata: {'source': 'data/Python_Notes.pdf', 'page_label': '3', 'moddate': '2024-06-15T22:44:10+02:00', 'page': 2, 'creationdate': '2024-06-16T02:12:11+05:30', 'creator': 'Microsoft® Word for Microsoft 365', 'author': 'Harry Codes', 'producer': '3.0.10 (5.0.18)', 'total_pages': 61}

# %% [markdown]
# # Step 7: Retrieve Relevant Content

# %%
# Retrieve Relevant Content

query = "What is machine learning?"

relevant_docs = retriever.invoke(query)

context = "\n\n".join(
    doc.page_content
    for doc in relevant_docs
)

print("Relevant context retrieved successfully")

print("\n--- Retrieved Context ---\n")
print(context)

print("\n--- Sources ---")

for i, doc in enumerate(relevant_docs, start=1):
    print(
        f"Chunk {i} → "
        f"Page: {doc.metadata.get('page')}, "
        f"Source: {doc.metadata.get('source')}"
    )
# Out:
# Relevant context retrieved successfully
#
# --- Retrieved Context ---
#
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ................................ ................................ .................... 6
# What is Python? ................................ ................................ .............................................................. 6
# Features of Python ................................ ................................ ................................ .......................... 6
#
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ................................ ................................ .................... 6
# What is Python? ................................ ................................ .............................................................. 6
# Features of Python ................................ ................................ ................................ .......................... 6
#
# Conclusion ................................ ................................ ................................................................ ..... 1
# Contents ................................ ................................................................ ................................ ........ 2
# Python programming Handbook ................................................................ ................................ .......... 6
# What is Programming? ................................ ................................ ................................ .................... 6
# What is Python? ................................ ................................ .............................................................. 6
# Features of Python ................................ ................................ ................................ .......................... 6
#
# --- Sources ---
# Chunk 1 → Page: 2, Source: data/Python_Notes.pdf
# Chunk 2 → Page: 2, Source: data/Python_Notes.pdf
# Chunk 3 → Page: 2, Source: data/Python_Notes.pdf

# %% [markdown]
# # Step 8: Initialize Gemini LLM

# %%
load_dotenv()

google_api_key = os.getenv("GEMINI_API_KEY")

if not google_api_key:
    print("GEMINI_API_KEY not found")
else:
    llm = ChatGoogleGenerativeAI(
        model="gemini-3.6-flash",
        temperature=0.2,
        google_api_key=google_api_key
    )

# %%
# Test Gemini

response = llm.invoke("What is Python?")
print(response.content)
# Out:
# C:\Users\Rohit singh\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': '**Python** is a popular, high-level, interpreted programming language known for its simplicity and readability. \n\nCreated by Guido van Rossum and first released in 1991, Python was designed with a philosophy that emphasizes code readability—it uses clean, English-like syntax rather than complex symbols, making it one of the easiest programming languages for beginners to learn.\n\n---\n\n### Key Features of Python\n\n1. **Easy to Read and Write:** Python code closely resembles natural English, which reduces the cost of program maintenance and makes it beginner-friendly.\n2. **Interpreted Language:** Python code is executed line-by-line, which makes testing and debugging faster and easier.\n3. **General-Purpose:** Python isn\'t designed for just one specific task; it can be used for web development, software creation, data analysis, and more.\n4. **Massive Ecosystem (Libraries & Frameworks):** Python has tens of thousands of pre-written pieces of code (libraries) that developers can use for free, saving time and effort.\n5. **Cross-Platform:** Python runs seamlessly on Windows, macOS, Linux, and other operating systems.\n\n---\n\n### What is Python Used For?\n\nPython is one of the most versatile languages in the world. Its main applications include:\n\n* **Artificial Intelligence & Machine Learning:** Python is the industry standard for AI, thanks to powerful libraries like *TensorFlow*, *PyTorch*, and *Scikit-learn*.\n* **Data Science & Visualization:** Data analysts use Python tools like *Pandas*, *NumPy*, and *Matplotlib* to analyze complex data sets and create graphs.\n* **Web Development:** Backend frameworks like *Django* and *Flask* allow developers to build scalable websites (used by companies like Instagram, Spotify, and Netflix).\n* **Automation & Scripting:** Python can automate repetitive daily tasks, such as renaming thousands of files, scraping text from websites, or sending automated emails.\n* **Software Development:** It is widely used for prototype creation, desktop applications, and backend utility tools.\n\n---\n\n### A Quick Example of Python Code\n\nTo print "Hello, World!" on the screen in Python, you only write one line:\n\n```python\nprint("Hello, World!")\n```\n\nFor comparison, doing the same thing in C++ or Java requires 4 to 6 lines of setup code.\n\n---\n\n### Summary\nPython is a multi-purpose tool used by everyone from complete coding novices to engineers at NASA, Google, and OpenAI. Its combination of **simplicity, powerful features, and a massive community** makes it one of the most in-demand programming languages today.', 'extras': {'signature': '...'}}]

# %% [markdown]
# # Step 9: Create RAG Chain

# %%
# Step 9: Create RAG Chain

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
You are a helpful AI assistant.

Answer the user's question using ONLY the context provided below.

If the answer is not available in the context, say:
"I could not find the answer in the provided PDF."

Context:
{context}

Question:
{question}

Answer:
""")

def rag_chain(question):

    # 1. Retrieve relevant documents
    relevant_docs = retriever.invoke(question)

    # 2. Combine retrieved chunks
    context = "\n\n".join(
        doc.page_content
        for doc in relevant_docs
    )

    # 3. Create prompt
    formatted_prompt = prompt.format(
        context=context,
        question=question
    )

    # 4. Ask Gemini
    response = llm.invoke(formatted_prompt)

    # 5. Extract text from Gemini response
    if isinstance(response.content, list):
        answer = "\n".join(
            item["text"]
            for item in response.content
            if isinstance(item, dict) and item.get("type") == "text"
        )
    else:
        answer = response.content

    return answer

# %%
question = "What is Python?"

answer = rag_chain(question)
print("AI:", answer)
# Out:
# C:\Users\Rohit singh\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# AI: Python is a simple and easy to understand language which feels like reading simple English. Its pseudo-code nature makes it easy to learn and understandable by beginners. Additionally, it is a programming language used to communicate with the computer.

# %% [markdown]
# # Step 10 — Final RAG Chatbot

# %%
# Final RAG Chatbot

def ask_rag(question):
    relevant_docs = retriever.invoke(question)

    context = "\n\n".join(
        doc.page_content
        for doc in relevant_docs
    )

    formatted_prompt = prompt.format(
        context=context,
        question=question
    )

    response = llm.invoke(formatted_prompt)

    # Extract text from Gemini response
    if isinstance(response.content, list):
        answer = "\n".join(
            item["text"]
            for item in response.content
            if isinstance(item, dict) and item.get("type") == "text"
        )
    else:
        answer = response.content

    return answer

# %%
question = "What is Python?"

answer = ask_rag(question)
print("\nAI:", answer)
# Out:
# C:\Users\Rohit singh\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# AI: Python is a simple and easy to understand language which feels like reading simple English. Its pseudo code nature makes it easy to learn and understandable by beginners. It is also a programming language used to communicate with the computer.

# %%
# Final RAG Chatbot

print("RAG AI Chatbot 🤖")
print("Type 'exit' to stop.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("AI: Goodbye! 👋")
        break

    answer = ask_rag(user_input)

    print("\nAI:", answer)
    print()
# Out:
# RAG AI Chatbot 🤖
# Type 'exit' to stop.
# You:  exit
# AI: Goodbye! 👋
